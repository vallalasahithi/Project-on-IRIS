# %%
### MAJOR PROJECT ###

# %%
#Build machine Learning model(classification) for the fruits dataset listed below
#Dataset link: https://www.kaggle.com/datasets/mjamilmoughal/fruits-with-colors-dataset
#Do data ingestion (convert dataset into dataframe)
#Do some preprocessing(if required)
#Identify the input and output columns. Remove the unwanted columns.
#Build multiple ML models(use different classification algorithms) and compare the accuracies.(Google the best classification algorithms and use a few common ones here).
#Evaluate the model.
#Create a streamlit app for the above model(optional)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/Rinex  Major project/archive (2).zip",sep='\t')
df
# Out:
#     fruit_label fruit_name     fruit_subtype  mass  width  height  color_score
# 0             1      apple      granny_smith   192    8.4     7.3         0.55
# 1             1      apple      granny_smith   180    8.0     6.8         0.59
# 2             1      apple      granny_smith   176    7.4     7.2         0.60
# 3             2   mandarin          mandarin    86    6.2     4.7         0.80
# 4             2   mandarin          mandarin    84    6.0     4.6         0.79
# 5             2   mandarin          mandarin    80    5.8     4.3         0.77
# 6             2   mandarin          mandarin    80    5.9     4.3         0.81
# 7             2   mandarin          mandarin    76    5.8     4.0         0.81
# 8             1      apple          braeburn   178    7.1     7.8         0.92
# 9             1      apple          braeburn   172    7.4     7.0         0.89
# 10            1      apple          braeburn   166    6.9     7.3         0.93
# 11            1      apple          braeburn   172    7.1     7.6         0.92
# 12            1      apple          braeburn   154    7.0     7.1         0.88
# 13            1      apple  golden_delicious   164    7.3     7.7         0.70
# 14            1      apple  golden_delicious   152    7.6     7.3         0.69
# 15            1      apple  golden_delicious   156    7.7     7.1         0.69
# 16            1      apple  golden_delicious   156    7.6     7.5         0.67
# 17            1      apple  golden_delicious   168    7.5     7.6         0.73
# 18            1      apple       cripps_pink   162    7.5     7.1         0.83
# 19            1      apple       cripps_pink   162    7.4     7.2         0.85
# 20            1      apple       cripps_pink   160    7.5     7.5         0.86
# 21            1      apple       cripps_pink   156    7.4     7.4         0.84
# 22            1      apple       cripps_pink   140    7.3     7.1         0.87
# 23            1      apple       cripps_pink   170    7.6     7.9         0.88
# 24            3     orange     spanish_jumbo   342    9.0     9.4         0.75
# 25            3     orange     spanish_jumbo   356    9.2     9.2         0.75
# 26            3     orange     spanish_jumbo   362    9.6     9.2         0.74
# 27            3     orange  selected_seconds   204    7.5     9.2         0.77
# 28            3     orange  selected_seconds   140    6.7     7.1         0.72
# 29            3     orange  selected_seconds   160    7.0     7.4         0.81
# 30            3     orange  selected_seconds   158    7.1     7.5         0.79
# 31            3     orange  selected_seconds   210    7.8     8.0         0.82
# 32            3     orange  selected_seconds   164    7.2     7.0         0.80
# 33            3     orange      turkey_navel   190    7.5     8.1         0.74
# 34            3     orange      turkey_navel   142    7.6     7.8         0.75
# 35            3     orange      turkey_navel   150    7.1     7.9         0.75
# 36            3     orange      turkey_navel   160    7.1     7.6         0.76
# 37            3     orange      turkey_navel   154    7.3     7.3         0.79
# 38            3     orange      turkey_navel   158    7.2     7.8         0.77
# 39            3     orange      turkey_navel   144    6.8     7.4         0.75
# 40            3     orange      turkey_navel   154    7.1     7.5         0.78
# 41            3     orange      turkey_navel   180    7.6     8.2         0.79
# 42            3     orange      turkey_navel   154    7.2     7.2         0.82
# 43            4      lemon    spanish_belsan   194    7.2    10.3         0.70
# 44            4      lemon    spanish_belsan   200    7.3    10.5         0.72
# 45            4      lemon    spanish_belsan   186    7.2     9.2         0.72
# 46            4      lemon    spanish_belsan   216    7.3    10.2         0.71
# 47            4      lemon    spanish_belsan   196    7.3     9.7         0.72
# 48            4      lemon    spanish_belsan   174    7.3    10.1         0.72
# 49            4      lemon           unknown   132    5.8     8.7         0.73
# 50            4      lemon           unknown   130    6.0     8.2         0.71
# 51            4      lemon           unknown   116    6.0     7.5         0.72
# 52            4      lemon           unknown   118    5.9     8.0         0.72
# 53            4      lemon           unknown   120    6.0     8.4         0.74
# 54            4      lemon           unknown   116    6.1     8.5         0.71
# 55            4      lemon           unknown   116    6.3     7.7         0.72
# 56            4      lemon           unknown   116    5.9     8.1         0.73
# 57            4      lemon           unknown   152    6.5     8.5         0.72
# 58            4      lemon           unknown   118    6.1     8.1         0.70

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# fruit_label      0
# fruit_name       0
# fruit_subtype    0
# mass             0
# width            0
# height           0
# color_score      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59 entries, 0 to 58
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   fruit_label    59 non-null     int64
#  1   fruit_name     59 non-null     object
#  2   fruit_subtype  59 non-null     object
#  3   mass           59 non-null     int64
#  4   width          59 non-null     float64
#  5   height         59 non-null     float64
#  6   color_score    59 non-null     float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 3.4+ KB

# %%
df.head()
# Out:
#    fruit_label fruit_name fruit_subtype  mass  width  height  color_score
# 0            1      apple  granny_smith   192    8.4     7.3         0.55
# 1            1      apple  granny_smith   180    8.0     6.8         0.59
# 2            1      apple  granny_smith   176    7.4     7.2         0.60
# 3            2   mandarin      mandarin    86    6.2     4.7         0.80
# 4            2   mandarin      mandarin    84    6.0     4.6         0.79

# %%
df.drop(columns=['fruit_label','color_score'],inplace=True)

# %%
df
# Out:
#    fruit_name     fruit_subtype  mass  width  height
# 0       apple      granny_smith   192    8.4     7.3
# 1       apple      granny_smith   180    8.0     6.8
# 2       apple      granny_smith   176    7.4     7.2
# 3    mandarin          mandarin    86    6.2     4.7
# 4    mandarin          mandarin    84    6.0     4.6
# 5    mandarin          mandarin    80    5.8     4.3
# 6    mandarin          mandarin    80    5.9     4.3
# 7    mandarin          mandarin    76    5.8     4.0
# 8       apple          braeburn   178    7.1     7.8
# 9       apple          braeburn   172    7.4     7.0
# 10      apple          braeburn   166    6.9     7.3
# 11      apple          braeburn   172    7.1     7.6
# 12      apple          braeburn   154    7.0     7.1
# 13      apple  golden_delicious   164    7.3     7.7
# 14      apple  golden_delicious   152    7.6     7.3
# 15      apple  golden_delicious   156    7.7     7.1
# 16      apple  golden_delicious   156    7.6     7.5
# 17      apple  golden_delicious   168    7.5     7.6
# 18      apple       cripps_pink   162    7.5     7.1
# 19      apple       cripps_pink   162    7.4     7.2
# 20      apple       cripps_pink   160    7.5     7.5
# 21      apple       cripps_pink   156    7.4     7.4
# 22      apple       cripps_pink   140    7.3     7.1
# 23      apple       cripps_pink   170    7.6     7.9
# 24     orange     spanish_jumbo   342    9.0     9.4
# 25     orange     spanish_jumbo   356    9.2     9.2
# 26     orange     spanish_jumbo   362    9.6     9.2
# 27     orange  selected_seconds   204    7.5     9.2
# 28     orange  selected_seconds   140    6.7     7.1
# 29     orange  selected_seconds   160    7.0     7.4
# 30     orange  selected_seconds   158    7.1     7.5
# 31     orange  selected_seconds   210    7.8     8.0
# 32     orange  selected_seconds   164    7.2     7.0
# 33     orange      turkey_navel   190    7.5     8.1
# 34     orange      turkey_navel   142    7.6     7.8
# 35     orange      turkey_navel   150    7.1     7.9
# 36     orange      turkey_navel   160    7.1     7.6
# 37     orange      turkey_navel   154    7.3     7.3
# 38     orange      turkey_navel   158    7.2     7.8
# 39     orange      turkey_navel   144    6.8     7.4
# 40     orange      turkey_navel   154    7.1     7.5
# 41     orange      turkey_navel   180    7.6     8.2
# 42     orange      turkey_navel   154    7.2     7.2
# 43      lemon    spanish_belsan   194    7.2    10.3
# 44      lemon    spanish_belsan   200    7.3    10.5
# 45      lemon    spanish_belsan   186    7.2     9.2
# 46      lemon    spanish_belsan   216    7.3    10.2
# 47      lemon    spanish_belsan   196    7.3     9.7
# 48      lemon    spanish_belsan   174    7.3    10.1
# 49      lemon           unknown   132    5.8     8.7
# 50      lemon           unknown   130    6.0     8.2
# 51      lemon           unknown   116    6.0     7.5
# 52      lemon           unknown   118    5.9     8.0
# 53      lemon           unknown   120    6.0     8.4
# 54      lemon           unknown   116    6.1     8.5
# 55      lemon           unknown   116    6.3     7.7
# 56      lemon           unknown   116    5.9     8.1
# 57      lemon           unknown   152    6.5     8.5
# 58      lemon           unknown   118    6.1     8.1

# %%
x=df.drop(columns=['fruit_name','fruit_subtype']).values
y=df['fruit_name'].values
y
# Out:
# array(['apple', 'apple', 'apple', 'mandarin', 'mandarin', 'mandarin',
#        'mandarin', 'mandarin', 'apple', 'apple', 'apple', 'apple',
#        'apple', 'apple', 'apple', 'apple', 'apple', 'apple', 'apple',
#        'apple', 'apple', 'apple', 'apple', 'apple', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'orange',
#        'orange', 'orange', 'orange', 'orange', 'orange', 'lemon', 'lemon',
#        'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon',
#        'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon', 'lemon'],
#       dtype=object)

# %%
df1=df[df['fruit_name']=='apple']         # splitting
df2=df[df['fruit_name']=='mandarin']
df3=df[df['fruit_name']=='orange']
df4=df[df['fruit_name']=='lemon']

# %%
plt.figure(figsize=(12,8))
plt.scatter(df1['width'],df1['height'],label='apple',color='r',marker='*')
plt.scatter(df2['width'],df2['height'],label='mandarin',color='g',marker='.')
plt.scatter(df3['width'],df3['height'],label='orange',color='orange',marker='o')
plt.scatter(df4['width'],df4['height'],label='lemon',color='y',marker='s')
plt.xlabel('Width',fontsize=20)
plt.ylabel('Height',fontsize=20)
plt.title('Width AND HEIGHTS OF DIFFERENT FRUITS',fontsize=20)
plt.xticks(np.arange(1,10,0.5))
plt.yticks(np.arange(1,10,0.5))
plt.legend()
plt.show()

# %%
# Splitting the dataset into training and testing dataset
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=2,test_size=0.1)

# %%
x_train.shape
# Out:
# (53, 3)

# %%
y_train.shape
# Out:
# (53,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train_scaled=sc.fit_transform(x_train)
x_test_scaled=sc.transform(x_test)

# %%
# KNN CLASSIFIER
from sklearn.neighbors import KNeighborsClassifier
model=KNeighborsClassifier(n_neighbors=7,metric='euclidean')

# %%
# training our model
model.fit(x_train_scaled,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=7)

# %%
y_p=model.predict(x_test_scaled)     # predicting
y_p
# Out:
# array(['lemon', 'orange', 'orange', 'lemon', 'apple', 'lemon'],
#       dtype=object)

# %%
y_test
# Out:
# array(['lemon', 'orange', 'orange', 'lemon', 'apple', 'lemon'],
#       dtype=object)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
accuracy_score(y_p,y_test)  #accuracy 100%
# Out:
# 1.0

# %%
print(classification_report(y_p,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      1.00      1.00         1
#        lemon       1.00      1.00      1.00         3
#       orange       1.00      1.00      1.00         2
#
#     accuracy                           1.00         6
#    macro avg       1.00      1.00      1.00         6
# weighted avg       1.00      1.00      1.00         6

# %%
 pd.DataFrame(confusion_matrix(y_p,y_test),index=['Apple_A','Lemon_A','Orange_A'],columns=['Apple_P','Lemon_P','Orange_P'])
# Out:
#           Apple_P  Lemon_P  Orange_P
# Apple_A         1        0         0
# Lemon_A         0        3         0
# Orange_A        0        0         2

# %%
 pd.DataFrame(confusion_matrix(y_p,y_test),index=['Apple_A','Lemon_A','Orange_A'],columns=['Apple_P','Lemon_P','Orange_P'])
# Out:
#           Apple_P  Lemon_P  Orange_P
# Apple_A         1        0         0
# Lemon_A         0        3         0
# Orange_A        0        0         2

# %%
# LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression
lr_model=LogisticRegression()

# %%
lr_model.fit(x_train_scaled,y_train)
# Out:
# LogisticRegression()

# %%
y_p1=lr_model.predict(x_test_scaled)
y_p1
# Out:
# array(['lemon', 'apple', 'orange', 'lemon', 'apple', 'lemon'],
#       dtype=object)

# %%
y_test
# Out:
# array(['lemon', 'orange', 'orange', 'lemon', 'apple', 'lemon'],
#       dtype=object)

# %%
accuracy_score(y_p1,y_test) #accuracy 83%
# Out:
# 0.8333333333333334

# %%
print(classification_report(y_p1,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        apple       1.00      0.50      0.67         2
#        lemon       1.00      1.00      1.00         3
#       orange       0.50      1.00      0.67         1
#
#     accuracy                           0.83         6
#    macro avg       0.83      0.83      0.78         6
# weighted avg       0.92      0.83      0.83         6

# %%
pd.DataFrame(confusion_matrix(y_p,y_test),index=['Apple_A','Lemon_A','Orange_A'],columns=['Apple_P','Lemon_P','Orange_P'])
# Out:
#           Apple_P  Lemon_P  Orange_P
# Apple_A         1        0         0
# Lemon_A         0        3         0
# Orange_A        0        0         2

# %%
plt.scatter(y_p1,y_test,marker='s')
plt.grid()
plt.show()

# %%
# DECISION TREE CLASSIFIER
from sklearn.tree import DecisionTreeClassifier
dc_model=DecisionTreeClassifier()
dc_model.fit(x_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_p2=dc_model.predict(x_test_scaled)
y_p2
# Out:
# array(['lemon', 'apple', 'apple', 'lemon', 'orange', 'lemon'],
#       dtype=object)

# %%
y_test
# Out:
# array(['lemon', 'orange', 'orange', 'lemon', 'apple', 'lemon'],
#       dtype=object)

# %%
accuracy_score(y_p2,y_test)  #acuuracy 83%
# Out:
# 0.5

# %%
print(classification_report(y_p2,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.00      0.00      0.00         2
#        lemon       1.00      1.00      1.00         3
#       orange       0.00      0.00      0.00         1
#
#     accuracy                           0.50         6
#    macro avg       0.33      0.33      0.33         6
# weighted avg       0.50      0.50      0.50         6

# %%
plt.scatter(y_p2,y_test,marker='s')
plt.grid()
plt.show()

# %%
# RANDOM FOREST CLASSIFIER
from sklearn.ensemble import RandomForestClassifier
rf_model=RandomForestClassifier()

# %%
rf_model.fit(x_train_scaled,y_train)
# Out:
# RandomForestClassifier()

# %%
y_p3=rf_model.predict(x_test_scaled)
y_p3
# Out:
# array(['lemon', 'orange', 'orange', 'lemon', 'orange', 'lemon'],
#       dtype=object)

# %%
y_test
# Out:
# array(['lemon', 'orange', 'orange', 'lemon', 'apple', 'lemon'],
#       dtype=object)

# %%
accuracy_score(y_p3,y_test) #accuracy 100%
# Out:
# 0.8333333333333334

# %%
print(classification_report(y_p3,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        apple       0.00      0.00      0.00         0
#        lemon       1.00      1.00      1.00         3
#       orange       1.00      0.67      0.80         3
#
#     accuracy                           0.83         6
#    macro avg       0.67      0.56      0.60         6
# weighted avg       1.00      0.83      0.90         6
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
plt.scatter(y_p3,y_test,marker='s')
plt.grid()
plt.show()
